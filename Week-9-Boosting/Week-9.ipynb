# %% [markdown]
# # Week 9 - Ensemble Learning: Boosting
#
# Last week, we saw that **bagging** (**b**ootstrap **agg**regation) averages multiple classifiers or regressors fitted to different bootstrapped data samples, which has the effect of reducing the variance of the individual models and regularizing their fits to improve generalization (test performance).
#
# This week, we continue our work with ensemble models, of which bagging is a special case. This week we cover **boosting**.
#
# Boosting throws out bootstrapping in favor of sequential samples that push the individual models to focus on points where the model makes errors. This is primarily used to solve underfitting.

# %% [markdown]
# # Lecture 16 - Boosting and AdaBoost
#
# First, let's import some things.

# %%
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.datasets import load_breast_cancer
from sklearn.datasets import load_wine
from sklearn.ensemble import AdaBoostClassifier, AdaBoostRegressor
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

from tensorflow.keras.datasets import mnist
from tensorflow.keras.datasets import cifar10
# Out:
# 2026-02-14 12:50:32.141747: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-14 12:50:32.166385: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI AVX_VNNI_INT8 AVX_NE_CONVERT FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-14 12:50:32.703958: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
data = load_breast_cancer()

X = data['data']
Y = data['target']

# split the data into train and test sets
trainX, testX, trainY, testY = train_test_split(X, Y, test_size = 0.25)

# build the classifier
model = AdaBoostClassifier()

# fit the classifier to the training data
model.fit(trainX, trainY)

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
plt.figure()
# Out:
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       156
#            1       1.00      1.00      1.00       270
#
#     accuracy                           1.00       426
#    macro avg       1.00      1.00      1.00       426
# weighted avg       1.00      1.00      1.00       426
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        56
#            1       0.99      0.98      0.98        87
#
#     accuracy                           0.98       143
#    macro avg       0.98      0.98      0.98       143
# weighted avg       0.98      0.98      0.98       143
#
#
# Testing Confusion Matrix:

# %%
data = load_wine()

X = data['data']
Y = data['target']

# split the data into train and test sets
trainX, testX, trainY, testY = train_test_split(X, Y, test_size = 0.25)

# build the classifier
model = AdaBoostClassifier()

# fit the classifier to the training data
model.fit(trainX, trainY)

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
plt.figure()
# Out:
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        44
#            1       1.00      1.00      1.00        49
#            2       1.00      1.00      1.00        40
#
#     accuracy                           1.00       133
#    macro avg       1.00      1.00      1.00       133
# weighted avg       1.00      1.00      1.00       133
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      0.93      0.97        15
#            1       0.91      0.95      0.93        22
#            2       0.88      0.88      0.88         8
#
#     accuracy                           0.93        45
#    macro avg       0.93      0.92      0.92        45
# weighted avg       0.94      0.93      0.93        45
#
#
# Testing Confusion Matrix:

# %% [markdown]
# Let's try the MNIST dataset with AdaBoost.

# %%
(trainX, trainY), (testX, testY) = mnist.load_data()

# preprocess the data
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1] * trainX.shape[2])
trainX = trainX.astype('float')/255.0

testX = testX.reshape(testX.shape[0], testX.shape[1] * testX.shape[2])
testX = testX.astype('float')/255.0

# build the classifier
model = AdaBoostClassifier(n_estimators = 100)

# fit the classifier to the training data
model.fit(trainX, trainY)

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
plt.figure()
# Out:
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.87      0.62      0.73      5923
#            1       0.88      0.88      0.88      6742
#            2       0.69      0.72      0.71      5958
#            3       0.67      0.64      0.65      6131
#            4       0.66      0.75      0.70      5842
#            5       0.47      0.52      0.50      5421
#            6       0.82      0.81      0.81      5918
#            7       0.82      0.73      0.77      6265
#            8       0.61      0.77      0.68      5851
#            9       0.58      0.53      0.55      5949
#
#     accuracy                           0.70     60000
#    macro avg       0.71      0.70      0.70     60000
# weighted avg       0.71      0.70      0.70     60000
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.85      0.66      0.74       980
#            1       0.89      0.87      0.88      1135
#            2       0.73      0.72      0.73      1032
#            3       0.67      0.64      0.66      1010
#            4       0.64      0.76      0.70       982
#            5       0.47      0.51      0.49       892
#            6       0.81      0.79      0.80       958
#            7       0.84      0.73      0.78      1028
#            8       0.59      0.78      0.67       974
#            9       0.59      0.53      0.56      1009
#
#     accuracy                           0.70     10000
#    macro avg       0.71      0.70      0.70     10000
# weighted avg       0.71      0.70      0.70     10000
#
#
# Testing Confusion Matrix:

# %% [markdown]
# Let's make the individual classifiers a little more sophisticated.

# %%
(trainX, trainY), (testX, testY) = mnist.load_data()

# preprocess the data
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1] * trainX.shape[2])
trainX = trainX.astype('float')/255.0

testX = testX.reshape(testX.shape[0], testX.shape[1] * testX.shape[2])
testX = testX.astype('float')/255.0

# build the classifier
model = AdaBoostClassifier(DecisionTreeClassifier(max_depth=None))

# fit the classifier to the training data
model.fit(trainX, trainY)

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
plt.figure()
# Out:
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5923
#            1       1.00      1.00      1.00      6742
#            2       1.00      1.00      1.00      5958
#            3       1.00      1.00      1.00      6131
#            4       1.00      1.00      1.00      5842
#            5       1.00      1.00      1.00      5421
#            6       1.00      1.00      1.00      5918
#            7       1.00      1.00      1.00      6265
#            8       1.00      1.00      1.00      5851
#            9       1.00      1.00      1.00      5949
#
#     accuracy                           1.00     60000
#    macro avg       1.00      1.00      1.00     60000
# weighted avg       1.00      1.00      1.00     60000
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       980
#            1       0.95      0.96      0.96      1135
#            2       0.86      0.85      0.85      1032
#            3       0.83      0.85      0.84      1010
#            4       0.88      0.88      0.88       982
#            5       0.85      0.83      0.84       892
#            6       0.90      0.89      0.89       958
#            7       0.92      0.90      0.91      1028
#            8       0.83      0.82      0.82       974
#            9       0.86      0.86      0.86      1009
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000
#
#
# Testing Confusion Matrix:

# %%
(trainX, trainY), (testX, testY) = cifar10.load_data()

# preprocess the data
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1] * trainX.shape[2] * 3)
trainX = trainX.astype('float')/255.0

testX = testX.reshape(testX.shape[0], testX.shape[1] * testX.shape[2] * 3)
testX = testX.astype('float')/255.0

# build the classifier
model = AdaBoostClassifier()

# fit the classifier to the training data
model.fit(trainX, trainY)

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
plt.figure()
# Out:
# /home/rwhite/.local/share/mamba/envs/xai-s26/lib/python3.11/site-packages/keras/src/datasets/cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")
# /home/rwhite/.local/share/mamba/envs/xai-s26/lib/python3.11/site-packages/sklearn/utils/validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.32      0.39      0.35      5000
#            1       0.32      0.32      0.32      5000
#            2       0.17      0.34      0.23      5000
#            3       0.17      0.15      0.16      5000
#            4       0.16      0.10      0.13      5000
#            5       0.26      0.20      0.22      5000
#            6       0.28      0.19      0.23      5000
#            7       0.27      0.21      0.24      5000
#            8       0.32      0.35      0.34      5000
#            9       0.36      0.32      0.34      5000
#
#     accuracy                           0.26     50000
#    macro avg       0.26      0.26      0.25     50000
# weighted avg       0.26      0.26      0.25     50000
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.31      0.39      0.35      1000
#            1       0.34      0.32      0.33      1000
#            2       0.16      0.32      0.22      1000
#            3       0.17      0.14      0.15      1000
#            4       0.17      0.11      0.13      1000
#            5       0.27      0.20      0.23      1000
#            6       0.26      0.19      0.22      1000
#            7       0.25      0.22      0.23      1000
#            8       0.31      0.35      0.33      1000
#            9       0.35      0.30      0.32      1000
#
#     accuracy                           0.25     10000
#    macro avg       0.26      0.25      0.25     10000
# weighted avg       0.26      0.25      0.25     10000
#
#
# Testing Confusion Matrix:

# %% [markdown]
# # Lecture 17 - Gradient Boosting
#
# We previously discussed boosting and AdaBoost, a powerful ensemble method for classification or regression.
#
# This week, we will learn about another variation of boosting: **gradient boosting** and the **XGBoost** algorithm, currently one of the best classifiers for many problems.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn

from sklearn.datasets import load_breast_cancer
from sklearn.datasets import load_wine
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.inspection import permutation_importance
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

from tensorflow.keras.datasets import mnist
from tensorflow.keras.datasets import cifar10

# %% [markdown]
# Let's try gradient boosting.

# %%
(trainX, trainY), (testX, testY) = mnist.load_data()

trainX = trainX[:10000]
trainY = trainY[:10000]

testX = testX[:1000]
testY = testY[:1000]

# preprocess the data
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1] * trainX.shape[2])
trainX = trainX.astype('float')/255.0

testX = testX.reshape(testX.shape[0], testX.shape[1] * testX.shape[2])
testX = testX.astype('float')/255.0

# build the classifier
model = GradientBoostingClassifier(verbose = 1)

# fit the classifier to the training data
model.fit(trainX, trainY)

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
plt.figure()
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.8954            3.19m
#          2           1.6553            3.15m
#          3           1.4853            3.12m
#          4           1.3380            3.09m
#          5           1.2215            3.06m
#          6           1.1169            3.03m
#          7           1.0331            2.99m
#          8           0.9617            2.96m
#          9           0.8929            2.93m
#         10           0.8356            2.90m
#         20           0.4939            2.58m
#         30           0.3410            2.26m
#         40           0.2574            1.93m
#         50           0.2060            1.61m
#         60           0.1688            1.29m
#         70           0.1415           58.02s
#         80           0.1202           38.67s
#         90           0.1024           19.33s
#        100           0.0879            0.00s
#
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1001
#            1       1.00      1.00      1.00      1127
#            2       0.99      0.98      0.99       991
#            3       0.98      0.97      0.98      1032
#            4       0.99      0.99      0.99       980
#            5       0.99      0.99      0.99       863
#            6       0.99      1.00      1.00      1014
#            7       0.99      0.99      0.99      1070
#            8       0.98      0.99      0.99       944
#            9       0.98      0.98      0.98       978
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96        85
#            1       0.97      0.98      0.97       126
#            2       0.95      0.87      0.91       116
#            3       0.88      0.85      0.87       107
#            4       0.89      0.92      0.91       110
#            5       0.88      0.86      0.87        87
#            6       0.90      0.87      0.89        87
#            7       0.86      0.90      0.88        99
#            8       0.81      0.84      0.82        89
#            9       0.87      0.89      0.88        94
#
#     accuracy                           0.90      1000
#    macro avg       0.90      0.90      0.90      1000
# weighted avg       0.90      0.90      0.90      1000
#
#
# Testing Confusion Matrix:

# %% [markdown]
# Note that we ran with a training set of just 10,000 images because gradient boosting is incapable of parallelization and is, therefore, rather slow.

# %% [markdown]
# Let's also try the `HistGradientBoostingClassifier`, an implementation of an algorithm similar to ordinary `GradientBoostingClassifier` but it sometimes runs much faster on large datasets. It is a `scikit-learn` implementation based on Microsoft's [Light GBM](https://github.com/Microsoft/LightGBM).

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

(trainX, trainY), (testX, testY) = mnist.load_data()

# preprocess the data
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1] * trainX.shape[2])
trainX = trainX.astype('float')/255.0

testX = testX.reshape(testX.shape[0], testX.shape[1] * testX.shape[2])
testX = testX.astype('float')/255.0

# build the classifier
model = HistGradientBoostingClassifier(verbose = 1)

# fit the classifier to the training data
model.fit(trainX, trainY)

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
plt.figure()
# Out:
# Binning 0.339 GB of training data: 0.419 s
# Binning 0.038 GB of validation data: 0.039 s
# Fitting gradient boosted rounds:
# Fit 1000 trees in 46.238 s, (31000 total leaves)
# Time spent computing histograms: 35.600s
# Time spent finding best splits:  6.113s
# Time spent applying splits:      3.217s
# Time spent predicting:           0.113s
#
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5923
#            1       1.00      1.00      1.00      6742
#            2       1.00      1.00      1.00      5958
#            3       1.00      1.00      1.00      6131
#            4       1.00      1.00      1.00      5842
#            5       1.00      1.00      1.00      5421
#            6       1.00      1.00      1.00      5918
#            7       1.00      1.00      1.00      6265
#            8       1.00      1.00      1.00      5851
#            9       1.00      1.00      1.00      5949
#
#     accuracy                           1.00     60000
#    macro avg       1.00      1.00      1.00     60000
# weighted avg       1.00      1.00      1.00     60000
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.97      0.97      0.97      1032
#            3       0.98      0.98      0.98      1010
#            4       0.99      0.97      0.98       982
#            5       0.98      0.97      0.98       892
#            6       0.98      0.98      0.98       958
#            7       0.97      0.97      0.97      1028
#            8       0.97      0.98      0.97       974
#            9       0.98      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000
#
#
# Testing Confusion Matrix:

# %% [markdown]
# This method runs way faster and has better accuracy.

# %% [markdown]
# ## CIFAR-10 Examples

# %%
from sklearn.ensemble import ExtraTreesClassifier

(trainX, trainY), (testX, testY) = cifar10.load_data()

# preprocess the data
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1] * trainX.shape[2] * 3)
trainX = trainX.astype('float')/255.0

testX = testX.reshape(testX.shape[0], testX.shape[1] * testX.shape[2] * 3)
testX = testX.astype('float')/255.0

# build the classifier
model = ExtraTreesClassifier(verbose = 2, n_jobs = -1)

# fit the classifier to the training data
model.fit(trainX, trainY.ravel())

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
plt.figure()
# Out:
# /home/rwhite/.local/share/mamba/envs/xai-s26/lib/python3.11/site-packages/keras/src/datasets/cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 24 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    3.7s finished
# [Parallel(n_jobs=24)]: Using backend ThreadingBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done 100 out of 100 | elapsed:    0.3s finished
# [Parallel(n_jobs=24)]: Using backend ThreadingBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=24)]: Using backend ThreadingBackend with 24 concurrent workers.
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5000
#            1       1.00      1.00      1.00      5000
#            2       1.00      1.00      1.00      5000
#            3       1.00      1.00      1.00      5000
#            4       1.00      1.00      1.00      5000
#            5       1.00      1.00      1.00      5000
#            6       1.00      1.00      1.00      5000
#            7       1.00      1.00      1.00      5000
#            8       1.00      1.00      1.00      5000
#            9       1.00      1.00      1.00      5000
#
#     accuracy                           1.00     50000
#    macro avg       1.00      1.00      1.00     50000
# weighted avg       1.00      1.00      1.00     50000
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.56      0.58      0.57      1000
#            1       0.51      0.53      0.52      1000
#            2       0.39      0.34      0.36      1000
#            3       0.34      0.27      0.30      1000
#            4       0.39      0.40      0.39      1000
#            5       0.44      0.40      0.42      1000
#            6       0.47      0.57      0.52      1000
#            7       0.52      0.45      0.48      1000
#            8       0.57      0.63      0.60      1000
#            9       0.49      0.56      0.52      1000
#
#     accuracy                           0.47     10000
#    macro avg       0.47      0.47      0.47     10000
# weighted avg       0.47      0.47      0.47     10000
#
#
# Testing Confusion Matrix:
# [Parallel(n_jobs=24)]: Done 100 out of 100 | elapsed:    0.1s finished

# %% [markdown]
# ### Breast Cancer Classification

# %%
from xgboost import XGBClassifier

# %%
cancer = load_breast_cancer()

X = cancer['data']
Y = cancer['target']

# split the data into train and test sets
trainX, testX, trainY, testY = train_test_split(X, Y, test_size = 0.25)
valX, testX, valY, testY = train_test_split(testX, testY, test_size = 0.5)

# build the classifier
model = XGBClassifier(n_jobs = -1)

# fit the classifier to the training data
model.fit(trainX, trainY, eval_set = [(valX, valY)])

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metricsl
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
plt.figure()
# Out:
# [0]	validation_0-logloss:0.42796
# [1]	validation_0-logloss:0.32280
# [2]	validation_0-logloss:0.25614
# [3]	validation_0-logloss:0.21388
# [4]	validation_0-logloss:0.18564
# [5]	validation_0-logloss:0.15888
# [6]	validation_0-logloss:0.13534
# [7]	validation_0-logloss:0.11649
# [8]	validation_0-logloss:0.10376
# [9]	validation_0-logloss:0.09199
# [10]	validation_0-logloss:0.08827
# [11]	validation_0-logloss:0.08156
# [12]	validation_0-logloss:0.07626
# [13]	validation_0-logloss:0.07749
# [14]	validation_0-logloss:0.07547
# [15]	validation_0-logloss:0.07726
# [16]	validation_0-logloss:0.07772
# [17]	validation_0-logloss:0.07622
# [18]	validation_0-logloss:0.07551
# [19]	validation_0-logloss:0.07328
# [20]	validation_0-logloss:0.07137
# [21]	validation_0-logloss:0.07366
# [22]	validation_0-logloss:0.07205
# [23]	validation_0-logloss:0.06998
# [24]	validation_0-logloss:0.06937
# [25]	validation_0-logloss:0.07067
# [26]	validation_0-logloss:0.07118
# [27]	validation_0-logloss:0.07487
# [28]	validation_0-logloss:0.07312
# [29]	validation_0-logloss:0.07194
# [30]	validation_0-logloss:0.07228
# [31]	validation_0-logloss:0.07575
# [32]	validation_0-logloss:0.07425
# [33]	validation_0-logloss:0.07487
# [34]	validation_0-logloss:0.07529
# [35]	validation_0-logloss:0.07651
# [36]	validation_0-logloss:0.07532
# [37]	validation_0-logloss:0.07439
# [38]	validation_0-logloss:0.07361
# [39]	validation_0-logloss:0.07464
# [40]	validation_0-logloss:0.07459
# [41]	validation_0-logloss:0.07502
# [42]	validation_0-logloss:0.07487
# [43]	validation_0-logloss:0.07442
# [44]	validation_0-logloss:0.07559
# [45]	validation_0-logloss:0.07502
# [46]	validation_0-logloss:0.07608
# [47]	validation_0-logloss:0.07545
# [48]	validation_0-logloss:0.07487
# [49]	validation_0-logloss:0.07444
# [50]	validation_0-logloss:0.07400
# [51]	validation_0-logloss:0.07431
# [52]	validation_0-logloss:0.07374
# [53]	validation_0-logloss:0.07415
# [54]	validation_0-logloss:0.07517
# [55]	validation_0-logloss:0.07476
# [56]	validation_0-logloss:0.07402
# [57]	validation_0-logloss:0.07435
# [58]	validation_0-logloss:0.07394
# [59]	validation_0-logloss:0.07350
# [60]	validation_0-logloss:0.07445
# [61]	validation_0-logloss:0.07405
# [62]	validation_0-logloss:0.07454
# [63]	validation_0-logloss:0.07398
# [64]	validation_0-logloss:0.07413
# [65]	validation_0-logloss:0.07374
# [66]	validation_0-logloss:0.07310
# [67]	validation_0-logloss:0.07273
# [68]	validation_0-logloss:0.07369
# [69]	validation_0-logloss:0.07417
# [70]	validation_0-logloss:0.07381
# [71]	validation_0-logloss:0.07469
# [72]	validation_0-logloss:0.07433
# [73]	validation_0-logloss:0.07386
# [74]	validation_0-logloss:0.07343
# [75]	validation_0-logloss:0.07315
# [76]	validation_0-logloss:0.07420
# [77]	validation_0-logloss:0.07448
# [78]	validation_0-logloss:0.07389
# [79]	validation_0-logloss:0.07361
# [80]	validation_0-logloss:0.07320
# [81]	validation_0-logloss:0.07409
# [82]	validation_0-logloss:0.07454
# [83]	validation_0-logloss:0.07414
# [84]	validation_0-logloss:0.07517
# [85]	validation_0-logloss:0.07485
# [86]	validation_0-logloss:0.07439
# [87]	validation_0-logloss:0.07410
# [88]	validation_0-logloss:0.07440
# [89]	validation_0-logloss:0.07486
# [90]	validation_0-logloss:0.07576
# [91]	validation_0-logloss:0.07534
# [92]	validation_0-logloss:0.07552
# [93]	validation_0-logloss:0.07596
# [94]	validation_0-logloss:0.07566
# [95]	validation_0-logloss:0.07660
# [96]	validation_0-logloss:0.07703
# [97]	validation_0-logloss:0.07666
# [98]	validation_0-logloss:0.07686
# [99]	validation_0-logloss:0.07727
#
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       154
#            1       1.00      1.00      1.00       272
#
#     accuracy                           1.00       426
#    macro avg       1.00      1.00      1.00       426
# weighted avg       1.00      1.00      1.00       426
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        34
#            1       0.95      1.00      0.97        38
#
#     accuracy                           0.97        72
#    macro avg       0.97      0.97      0.97        72
# weighted avg       0.97      0.97      0.97        72
#
#
# Testing Confusion Matrix:

# %%
result = permutation_importance(model, testX, testY, n_repeats = 10, n_jobs = -1)
sorted_idx = result.importances_mean.argsort()

fig, ax = plt.subplots()
ax.boxplot(result.importances[sorted_idx].T, vert = False,
           labels = cancer.feature_names[sorted_idx])
ax.set_title("Permutation Importances (test set)")
fig.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_137181/3739344472.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(result.importances[sorted_idx].T, vert = False,

# %% [markdown]
# ### Wine Example

# %%
wine = load_wine()

X = wine['data']
Y = wine['target']

# split the data into train and test sets
trainX, testX, trainY, testY = train_test_split(X, Y, test_size = 0.25)
valX, testX, valY, testY = train_test_split(testX, testY, test_size = 0.5)

# build the classifier
model = XGBClassifier(n_jobs = -1)

# fit the classifier to the training data
model.fit(trainX, trainY, eval_set = [(valX, valY)])

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
plt.figure()
# Out:
# [0]	validation_0-mlogloss:0.72392
# [1]	validation_0-mlogloss:0.52008
# [2]	validation_0-mlogloss:0.38712
# [3]	validation_0-mlogloss:0.29767
# [4]	validation_0-mlogloss:0.22580
# [5]	validation_0-mlogloss:0.17689
# [6]	validation_0-mlogloss:0.14263
# [7]	validation_0-mlogloss:0.11532
# [8]	validation_0-mlogloss:0.09624
# [9]	validation_0-mlogloss:0.08188
# [10]	validation_0-mlogloss:0.07125
# [11]	validation_0-mlogloss:0.06277
# [12]	validation_0-mlogloss:0.05366
# [13]	validation_0-mlogloss:0.04767
# [14]	validation_0-mlogloss:0.04284
# [15]	validation_0-mlogloss:0.03842
# [16]	validation_0-mlogloss:0.03624
# [17]	validation_0-mlogloss:0.03412
# [18]	validation_0-mlogloss:0.03202
# [19]	validation_0-mlogloss:0.03056
# [20]	validation_0-mlogloss:0.02804
# [21]	validation_0-mlogloss:0.02682
# [22]	validation_0-mlogloss:0.02526
# [23]	validation_0-mlogloss:0.02418
# [24]	validation_0-mlogloss:0.02344
# [25]	validation_0-mlogloss:0.02258
# [26]	validation_0-mlogloss:0.02207
# [27]	validation_0-mlogloss:0.02178
# [28]	validation_0-mlogloss:0.02159
# [29]	validation_0-mlogloss:0.02144
# [30]	validation_0-mlogloss:0.02139
# [31]	validation_0-mlogloss:0.02127
# [32]	validation_0-mlogloss:0.02122
# [33]	validation_0-mlogloss:0.02111
# [34]	validation_0-mlogloss:0.02071
# [35]	validation_0-mlogloss:0.02051
# [36]	validation_0-mlogloss:0.02044
# [37]	validation_0-mlogloss:0.02011
# [38]	validation_0-mlogloss:0.02005
# [39]	validation_0-mlogloss:0.01975
# [40]	validation_0-mlogloss:0.01973
# [41]	validation_0-mlogloss:0.01969
# [42]	validation_0-mlogloss:0.01968
# [43]	validation_0-mlogloss:0.01956
# [44]	validation_0-mlogloss:0.01955
# [45]	validation_0-mlogloss:0.01953
# [46]	validation_0-mlogloss:0.01929
# [47]	validation_0-mlogloss:0.01908
# [48]	validation_0-mlogloss:0.01913
# [49]	validation_0-mlogloss:0.01912
# [50]	validation_0-mlogloss:0.01912
# [51]	validation_0-mlogloss:0.01911
# [52]	validation_0-mlogloss:0.01911
# [53]	validation_0-mlogloss:0.01911
# [54]	validation_0-mlogloss:0.01910
# [55]	validation_0-mlogloss:0.01910
# [56]	validation_0-mlogloss:0.01910
# [57]	validation_0-mlogloss:0.01910
# [58]	validation_0-mlogloss:0.01910
# [59]	validation_0-mlogloss:0.01910
# [60]	validation_0-mlogloss:0.01909
# [61]	validation_0-mlogloss:0.01909
# [62]	validation_0-mlogloss:0.01909
# [63]	validation_0-mlogloss:0.01909
# [64]	validation_0-mlogloss:0.01909
# [65]	validation_0-mlogloss:0.01909
# [66]	validation_0-mlogloss:0.01909
# [67]	validation_0-mlogloss:0.01909
# [68]	validation_0-mlogloss:0.01909
# [69]	validation_0-mlogloss:0.01909
# [70]	validation_0-mlogloss:0.01909
# [71]	validation_0-mlogloss:0.01909
# [72]	validation_0-mlogloss:0.01909
# [73]	validation_0-mlogloss:0.01909
# [74]	validation_0-mlogloss:0.01909
# [75]	validation_0-mlogloss:0.01909
# [76]	validation_0-mlogloss:0.01909
# [77]	validation_0-mlogloss:0.01909
# [78]	validation_0-mlogloss:0.01909
# [79]	validation_0-mlogloss:0.01909
# [80]	validation_0-mlogloss:0.01909
# [81]	validation_0-mlogloss:0.01909
# [82]	validation_0-mlogloss:0.01909
# [83]	validation_0-mlogloss:0.01909
# [84]	validation_0-mlogloss:0.01909
# [85]	validation_0-mlogloss:0.01909
# [86]	validation_0-mlogloss:0.01909
# [87]	validation_0-mlogloss:0.01909
# [88]	validation_0-mlogloss:0.01909
# [89]	validation_0-mlogloss:0.01909
# [90]	validation_0-mlogloss:0.01909
# [91]	validation_0-mlogloss:0.01909
# [92]	validation_0-mlogloss:0.01909
# [93]	validation_0-mlogloss:0.01909
# [94]	validation_0-mlogloss:0.01909
# [95]	validation_0-mlogloss:0.01909
# [96]	validation_0-mlogloss:0.01909
# [97]	validation_0-mlogloss:0.01909
# [98]	validation_0-mlogloss:0.01909
# [99]	validation_0-mlogloss:0.01909
#
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        43
#            1       1.00      1.00      1.00        53
#            2       1.00      1.00      1.00        37
#
#     accuracy                           1.00       133
#    macro avg       1.00      1.00      1.00       133
# weighted avg       1.00      1.00      1.00       133
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.90      1.00      0.95         9
#            2       1.00      0.86      0.92         7
#
#     accuracy                           0.96        23
#    macro avg       0.97      0.95      0.96        23
# weighted avg       0.96      0.96      0.96        23
#
#
# Testing Confusion Matrix:

# %%
result = permutation_importance(model, testX, testY, n_repeats = 10, n_jobs = -1)
sorted_idx = result.importances_mean.argsort()

fig, ax = plt.subplots()
ax.boxplot(result.importances[sorted_idx].T, vert = False,
           labels = np.array(wine.feature_names)[sorted_idx])
ax.set_title("Permutation Importances (test set)")
fig.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_137181/4130887307.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(result.importances[sorted_idx].T, vert = False,

# %% [markdown]
# ### MNIST Example

# %%
(trainX, trainY), (testX, testY) = mnist.load_data()

# preprocess the data
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1] * trainX.shape[2])
trainX = trainX.astype('float')/255.0

testX = testX.reshape(testX.shape[0], testX.shape[1] * testX.shape[2])
testX = testX.astype('float')/255.0

valX, testX, valY, testY = train_test_split(testX, testY, test_size = 0.5)

# build the classifier
model = XGBClassifier(n_jobs = -1)

# fit the classifier to the training data
model.fit(trainX, trainY, eval_set = [(valX, valY)])

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
plt.figure()
# Out:
# [0]	validation_0-mlogloss:1.36680
# [1]	validation_0-mlogloss:1.04055
# [2]	validation_0-mlogloss:0.82878
# [3]	validation_0-mlogloss:0.68191
# [4]	validation_0-mlogloss:0.57066
# [5]	validation_0-mlogloss:0.48759
# [6]	validation_0-mlogloss:0.42336
# [7]	validation_0-mlogloss:0.36929
# [8]	validation_0-mlogloss:0.32798
# [9]	validation_0-mlogloss:0.29488
# [10]	validation_0-mlogloss:0.26612
# [11]	validation_0-mlogloss:0.24443
# [12]	validation_0-mlogloss:0.22714
# [13]	validation_0-mlogloss:0.21128
# [14]	validation_0-mlogloss:0.19846
# [15]	validation_0-mlogloss:0.18701
# [16]	validation_0-mlogloss:0.17702
# [17]	validation_0-mlogloss:0.16814
# [18]	validation_0-mlogloss:0.16009
# [19]	validation_0-mlogloss:0.15401
# [20]	validation_0-mlogloss:0.14813
# [21]	validation_0-mlogloss:0.14258
# [22]	validation_0-mlogloss:0.13754
# [23]	validation_0-mlogloss:0.13307
# [24]	validation_0-mlogloss:0.12863
# [25]	validation_0-mlogloss:0.12475
# [26]	validation_0-mlogloss:0.12124
# [27]	validation_0-mlogloss:0.11813
# [28]	validation_0-mlogloss:0.11543
# [29]	validation_0-mlogloss:0.11281
# [30]	validation_0-mlogloss:0.11035
# [31]	validation_0-mlogloss:0.10816
# [32]	validation_0-mlogloss:0.10571
# [33]	validation_0-mlogloss:0.10376
# [34]	validation_0-mlogloss:0.10212
# [35]	validation_0-mlogloss:0.10062
# [36]	validation_0-mlogloss:0.09869
# [37]	validation_0-mlogloss:0.09743
# [38]	validation_0-mlogloss:0.09612
# [39]	validation_0-mlogloss:0.09471
# [40]	validation_0-mlogloss:0.09328
# [41]	validation_0-mlogloss:0.09194
# [42]	validation_0-mlogloss:0.09100
# [43]	validation_0-mlogloss:0.08975
# [44]	validation_0-mlogloss:0.08852
# [45]	validation_0-mlogloss:0.08751
# [46]	validation_0-mlogloss:0.08656
# [47]	validation_0-mlogloss:0.08587
# [48]	validation_0-mlogloss:0.08499
# [49]	validation_0-mlogloss:0.08429
# [50]	validation_0-mlogloss:0.08364
# [51]	validation_0-mlogloss:0.08293
# [52]	validation_0-mlogloss:0.08292
# [53]	validation_0-mlogloss:0.08233
# [54]	validation_0-mlogloss:0.08152
# [55]	validation_0-mlogloss:0.08076
# [56]	validation_0-mlogloss:0.08008
# [57]	validation_0-mlogloss:0.07959
# [58]	validation_0-mlogloss:0.07882
# [59]	validation_0-mlogloss:0.07847
# [60]	validation_0-mlogloss:0.07792
# [61]	validation_0-mlogloss:0.07763
# [62]	validation_0-mlogloss:0.07695
# [63]	validation_0-mlogloss:0.07667
# [64]	validation_0-mlogloss:0.07612
# [65]	validation_0-mlogloss:0.07591
# [66]	validation_0-mlogloss:0.07525
# [67]	validation_0-mlogloss:0.07506
# [68]	validation_0-mlogloss:0.07458
# [69]	validation_0-mlogloss:0.07433
# [70]	validation_0-mlogloss:0.07407
# [71]	validation_0-mlogloss:0.07387
# [72]	validation_0-mlogloss:0.07342
# [73]	validation_0-mlogloss:0.07301
# [74]	validation_0-mlogloss:0.07268
# [75]	validation_0-mlogloss:0.07245
# [76]	validation_0-mlogloss:0.07216
# [77]	validation_0-mlogloss:0.07201
# [78]	validation_0-mlogloss:0.07203
# [79]	validation_0-mlogloss:0.07189
# [80]	validation_0-mlogloss:0.07163
# [81]	validation_0-mlogloss:0.07157
# [82]	validation_0-mlogloss:0.07154
# [83]	validation_0-mlogloss:0.07154
# [84]	validation_0-mlogloss:0.07139
# [85]	validation_0-mlogloss:0.07119
# [86]	validation_0-mlogloss:0.07101
# [87]	validation_0-mlogloss:0.07099
# [88]	validation_0-mlogloss:0.07097
# [89]	validation_0-mlogloss:0.07095
# [90]	validation_0-mlogloss:0.07088
# [91]	validation_0-mlogloss:0.07061
# [92]	validation_0-mlogloss:0.07043
# [93]	validation_0-mlogloss:0.07037
# [94]	validation_0-mlogloss:0.07013
# [95]	validation_0-mlogloss:0.07010
# [96]	validation_0-mlogloss:0.07015
# [97]	validation_0-mlogloss:0.07013
# [98]	validation_0-mlogloss:0.07003
# [99]	validation_0-mlogloss:0.07010
#
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5923
#            1       1.00      1.00      1.00      6742
#            2       1.00      1.00      1.00      5958
#            3       1.00      1.00      1.00      6131
#            4       1.00      1.00      1.00      5842
#            5       1.00      1.00      1.00      5421
#            6       1.00      1.00      1.00      5918
#            7       1.00      1.00      1.00      6265
#            8       1.00      1.00      1.00      5851
#            9       1.00      1.00      1.00      5949
#
#     accuracy                           1.00     60000
#    macro avg       1.00      1.00      1.00     60000
# weighted avg       1.00      1.00      1.00     60000
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       495
#            1       0.99      0.99      0.99       567
#            2       0.98      0.98      0.98       507
#            3       0.97      0.97      0.97       509
#            4       0.98      0.97      0.97       490
#            5       0.99      0.97      0.98       460
#            6       0.99      0.99      0.99       484
#            7       0.98      0.97      0.98       506
#            8       0.97      0.97      0.97       505
#            9       0.96      0.97      0.96       477
#
#     accuracy                           0.98      5000
#    macro avg       0.98      0.98      0.98      5000
# weighted avg       0.98      0.98      0.98      5000
#
#
# Testing Confusion Matrix:

# %% [markdown]
# Let's try to tune XGBoost with 5-fold cross-validation to see if we can improve the results.

# %%
parameters = {'max_depth': [1, 5, 10, 100, None], 'reg_lambda': [0.001, 0.01, 0.1, 1, 10]}
model = GridSearchCV(XGBClassifier(n_jobs = -1, eval_metric='mlogloss'), parameters, n_jobs = -1)

# build the classifier
model = XGBClassifier(n_jobs = -1)

# fit the classifier to the training data
model.fit(trainX, trainY, eval_set = [(valX, valY)])

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
plt.figure()
# Out:
# [0]	validation_0-mlogloss:1.36680
# [1]	validation_0-mlogloss:1.04055
# [2]	validation_0-mlogloss:0.82878
# [3]	validation_0-mlogloss:0.68191
# [4]	validation_0-mlogloss:0.57066
# [5]	validation_0-mlogloss:0.48759
# [6]	validation_0-mlogloss:0.42336
# [7]	validation_0-mlogloss:0.36929
# [8]	validation_0-mlogloss:0.32798
# [9]	validation_0-mlogloss:0.29488
# [10]	validation_0-mlogloss:0.26612
# [11]	validation_0-mlogloss:0.24443
# [12]	validation_0-mlogloss:0.22714
# [13]	validation_0-mlogloss:0.21128
# [14]	validation_0-mlogloss:0.19846
# [15]	validation_0-mlogloss:0.18701
# [16]	validation_0-mlogloss:0.17702
# [17]	validation_0-mlogloss:0.16814
# [18]	validation_0-mlogloss:0.16009
# [19]	validation_0-mlogloss:0.15401
# [20]	validation_0-mlogloss:0.14813
# [21]	validation_0-mlogloss:0.14258
# [22]	validation_0-mlogloss:0.13754
# [23]	validation_0-mlogloss:0.13307
# [24]	validation_0-mlogloss:0.12863
# [25]	validation_0-mlogloss:0.12475
# [26]	validation_0-mlogloss:0.12124
# [27]	validation_0-mlogloss:0.11813
# [28]	validation_0-mlogloss:0.11543
# [29]	validation_0-mlogloss:0.11281
# [30]	validation_0-mlogloss:0.11035
# [31]	validation_0-mlogloss:0.10816
# [32]	validation_0-mlogloss:0.10571
# [33]	validation_0-mlogloss:0.10376
# [34]	validation_0-mlogloss:0.10212
# [35]	validation_0-mlogloss:0.10062
# [36]	validation_0-mlogloss:0.09869
# [37]	validation_0-mlogloss:0.09743
# [38]	validation_0-mlogloss:0.09612
# [39]	validation_0-mlogloss:0.09471
# [40]	validation_0-mlogloss:0.09328
# [41]	validation_0-mlogloss:0.09194
# [42]	validation_0-mlogloss:0.09100
# [43]	validation_0-mlogloss:0.08975
# [44]	validation_0-mlogloss:0.08852
# [45]	validation_0-mlogloss:0.08751
# [46]	validation_0-mlogloss:0.08656
# [47]	validation_0-mlogloss:0.08587
# [48]	validation_0-mlogloss:0.08499
# [49]	validation_0-mlogloss:0.08429
# [50]	validation_0-mlogloss:0.08364
# [51]	validation_0-mlogloss:0.08293
# [52]	validation_0-mlogloss:0.08292
# [53]	validation_0-mlogloss:0.08233
# [54]	validation_0-mlogloss:0.08152
# [55]	validation_0-mlogloss:0.08076
# [56]	validation_0-mlogloss:0.08008
# [57]	validation_0-mlogloss:0.07959
# [58]	validation_0-mlogloss:0.07882
# [59]	validation_0-mlogloss:0.07847
# [60]	validation_0-mlogloss:0.07792
# [61]	validation_0-mlogloss:0.07763
# [62]	validation_0-mlogloss:0.07695
# [63]	validation_0-mlogloss:0.07667
# [64]	validation_0-mlogloss:0.07612
# [65]	validation_0-mlogloss:0.07591
# [66]	validation_0-mlogloss:0.07525
# [67]	validation_0-mlogloss:0.07506
# [68]	validation_0-mlogloss:0.07458
# [69]	validation_0-mlogloss:0.07433
# [70]	validation_0-mlogloss:0.07407
# [71]	validation_0-mlogloss:0.07387
# [72]	validation_0-mlogloss:0.07342
# [73]	validation_0-mlogloss:0.07301
# [74]	validation_0-mlogloss:0.07268
# [75]	validation_0-mlogloss:0.07245
# [76]	validation_0-mlogloss:0.07216
# [77]	validation_0-mlogloss:0.07201
# [78]	validation_0-mlogloss:0.07203
# [79]	validation_0-mlogloss:0.07189
# [80]	validation_0-mlogloss:0.07163
# [81]	validation_0-mlogloss:0.07157
# [82]	validation_0-mlogloss:0.07154
# [83]	validation_0-mlogloss:0.07154
# [84]	validation_0-mlogloss:0.07139
# [85]	validation_0-mlogloss:0.07119
# [86]	validation_0-mlogloss:0.07101
# [87]	validation_0-mlogloss:0.07099
# [88]	validation_0-mlogloss:0.07097
# [89]	validation_0-mlogloss:0.07095
# [90]	validation_0-mlogloss:0.07088
# [91]	validation_0-mlogloss:0.07061
# [92]	validation_0-mlogloss:0.07043
# [93]	validation_0-mlogloss:0.07037
# [94]	validation_0-mlogloss:0.07013
# [95]	validation_0-mlogloss:0.07010
# [96]	validation_0-mlogloss:0.07015
# [97]	validation_0-mlogloss:0.07013
# [98]	validation_0-mlogloss:0.07003
# [99]	validation_0-mlogloss:0.07010
#
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5923
#            1       1.00      1.00      1.00      6742
#            2       1.00      1.00      1.00      5958
#            3       1.00      1.00      1.00      6131
#            4       1.00      1.00      1.00      5842
#            5       1.00      1.00      1.00      5421
#            6       1.00      1.00      1.00      5918
#            7       1.00      1.00      1.00      6265
#            8       1.00      1.00      1.00      5851
#            9       1.00      1.00      1.00      5949
#
#     accuracy                           1.00     60000
#    macro avg       1.00      1.00      1.00     60000
# weighted avg       1.00      1.00      1.00     60000
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       495
#            1       0.99      0.99      0.99       567
#            2       0.98      0.98      0.98       507
#            3       0.97      0.97      0.97       509
#            4       0.98      0.97      0.97       490
#            5       0.99      0.97      0.98       460
#            6       0.99      0.99      0.99       484
#            7       0.98      0.97      0.98       506
#            8       0.97      0.97      0.97       505
#            9       0.96      0.97      0.96       477
#
#     accuracy                           0.98      5000
#    macro avg       0.98      0.98      0.98      5000
# weighted avg       0.98      0.98      0.98      5000
#
#
# Testing Confusion Matrix:

# %% [markdown]
# So, we tried, but made no gains.
#
# ### CIFAR10 Example

# %%
(trainX, trainY), (testX, testY) = cifar10.load_data()

# preprocess the data
trainX = trainX.reshape(trainX.shape[0], trainX.shape[1] * trainX.shape[2] * 3)
trainX = trainX.astype('float')/255.0

testX = testX.reshape(testX.shape[0], testX.shape[1] * testX.shape[2] * 3)
testX = testX.astype('float')/255.0

valX, testX, valY, testY = train_test_split(testX, testY, test_size = 0.5)

# build the classifier
model = XGBClassifier(n_jobs = -1)

# fit the classifier to the training data
model.fit(trainX, trainY.ravel(), eval_set = [(valX, valY.ravel())])

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
plt.figure()
# Out:
# /home/rwhite/.local/share/mamba/envs/xai-s26/lib/python3.11/site-packages/keras/src/datasets/cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")
# [0]	validation_0-mlogloss:2.13161
# [1]	validation_0-mlogloss:2.02609
# [2]	validation_0-mlogloss:1.94776
# [3]	validation_0-mlogloss:1.88604
# [4]	validation_0-mlogloss:1.83204
# [5]	validation_0-mlogloss:1.78916
# [6]	validation_0-mlogloss:1.75547
# [7]	validation_0-mlogloss:1.72422
# [8]	validation_0-mlogloss:1.69861
# [9]	validation_0-mlogloss:1.67655
# [10]	validation_0-mlogloss:1.65285
# [11]	validation_0-mlogloss:1.63435
# [12]	validation_0-mlogloss:1.61718
# [13]	validation_0-mlogloss:1.60097
# [14]	validation_0-mlogloss:1.58698
# [15]	validation_0-mlogloss:1.57375
# [16]	validation_0-mlogloss:1.56162
# [17]	validation_0-mlogloss:1.55080
# [18]	validation_0-mlogloss:1.53923
# [19]	validation_0-mlogloss:1.52839
# [20]	validation_0-mlogloss:1.51995
# [21]	validation_0-mlogloss:1.51195
# [22]	validation_0-mlogloss:1.50367
# [23]	validation_0-mlogloss:1.49582
# [24]	validation_0-mlogloss:1.48907
# [25]	validation_0-mlogloss:1.48348
# [26]	validation_0-mlogloss:1.47559
# [27]	validation_0-mlogloss:1.46799
# [28]	validation_0-mlogloss:1.46244
# [29]	validation_0-mlogloss:1.45585
# [30]	validation_0-mlogloss:1.45015
# [31]	validation_0-mlogloss:1.44564
# [32]	validation_0-mlogloss:1.44115
# [33]	validation_0-mlogloss:1.43509
# [34]	validation_0-mlogloss:1.43098
# [35]	validation_0-mlogloss:1.42620
# [36]	validation_0-mlogloss:1.42253
# [37]	validation_0-mlogloss:1.41870
# [38]	validation_0-mlogloss:1.41596
# [39]	validation_0-mlogloss:1.41204
# [40]	validation_0-mlogloss:1.40853
# [41]	validation_0-mlogloss:1.40554
# [42]	validation_0-mlogloss:1.40231
# [43]	validation_0-mlogloss:1.39884
# [44]	validation_0-mlogloss:1.39579
# [45]	validation_0-mlogloss:1.39310
# [46]	validation_0-mlogloss:1.39088
# [47]	validation_0-mlogloss:1.38842
# [48]	validation_0-mlogloss:1.38564
# [49]	validation_0-mlogloss:1.38259
# [50]	validation_0-mlogloss:1.37965
# [51]	validation_0-mlogloss:1.37650
# [52]	validation_0-mlogloss:1.37556
# [53]	validation_0-mlogloss:1.37332
# [54]	validation_0-mlogloss:1.36993
# [55]	validation_0-mlogloss:1.36695
# [56]	validation_0-mlogloss:1.36499
# [57]	validation_0-mlogloss:1.36355
# [58]	validation_0-mlogloss:1.36174
# [59]	validation_0-mlogloss:1.35939
# [60]	validation_0-mlogloss:1.35707
# [61]	validation_0-mlogloss:1.35456
# [62]	validation_0-mlogloss:1.35302
# [63]	validation_0-mlogloss:1.35180
# [64]	validation_0-mlogloss:1.34881
# [65]	validation_0-mlogloss:1.34754
# [66]	validation_0-mlogloss:1.34635
# [67]	validation_0-mlogloss:1.34537
# [68]	validation_0-mlogloss:1.34356
# [69]	validation_0-mlogloss:1.34171
# [70]	validation_0-mlogloss:1.33979
# [71]	validation_0-mlogloss:1.33818
# [72]	validation_0-mlogloss:1.33659
# [73]	validation_0-mlogloss:1.33506
# [74]	validation_0-mlogloss:1.33316
# [75]	validation_0-mlogloss:1.33205
# [76]	validation_0-mlogloss:1.33119
# [77]	validation_0-mlogloss:1.32985
# [78]	validation_0-mlogloss:1.32886
# [79]	validation_0-mlogloss:1.32615
# [80]	validation_0-mlogloss:1.32470
# [81]	validation_0-mlogloss:1.32238
# [82]	validation_0-mlogloss:1.32098
# [83]	validation_0-mlogloss:1.31916
# [84]	validation_0-mlogloss:1.31821
# [85]	validation_0-mlogloss:1.31646
# [86]	validation_0-mlogloss:1.31478
# [87]	validation_0-mlogloss:1.31320
# [88]	validation_0-mlogloss:1.31157
# [89]	validation_0-mlogloss:1.31051
# [90]	validation_0-mlogloss:1.30940
# [91]	validation_0-mlogloss:1.30816
# [92]	validation_0-mlogloss:1.30656
# [93]	validation_0-mlogloss:1.30678
# [94]	validation_0-mlogloss:1.30578
# [95]	validation_0-mlogloss:1.30509
# [96]	validation_0-mlogloss:1.30373
# [97]	validation_0-mlogloss:1.30285
# [98]	validation_0-mlogloss:1.30247
# [99]	validation_0-mlogloss:1.30184
#
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      5000
#            1       1.00      1.00      1.00      5000
#            2       0.97      0.98      0.98      5000
#            3       0.99      0.97      0.98      5000
#            4       0.95      0.98      0.97      5000
#            5       0.99      0.97      0.98      5000
#            6       0.98      0.99      0.98      5000
#            7       1.00      0.99      0.99      5000
#            8       0.99      0.99      0.99      5000
#            9       1.00      0.99      1.00      5000
#
#     accuracy                           0.99     50000
#    macro avg       0.99      0.99      0.99     50000
# weighted avg       0.99      0.99      0.99     50000
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.64      0.61      0.62       523
#            1       0.63      0.62      0.63       510
#            2       0.42      0.39      0.40       487
#            3       0.39      0.38      0.39       510
#            4       0.46      0.45      0.45       505
#            5       0.45      0.45      0.45       489
#            6       0.55      0.63      0.59       509
#            7       0.60      0.57      0.58       483
#            8       0.64      0.67      0.65       479
#            9       0.57      0.58      0.58       505
#
#     accuracy                           0.54      5000
#    macro avg       0.53      0.54      0.53      5000
# weighted avg       0.53      0.54      0.53      5000
#
#
# Testing Confusion Matrix:

# %%
parameters = {'max_depth': [1, 5, 10, 100, None], 'reg_lambda': [0.001, 0.01, 0.1, 1, 10]}

model = GridSearchCV(XGBClassifier(n_jobs = -1, eval_metric='mlogloss'), parameters, n_jobs = -1)

# build the classifier
model = XGBClassifier(n_jobs = -1)

# fit the classifier to the training data
model.fit(trainX, trainY.ravel(), eval_set = [(valX, valY.ravel())])

# predict the labels of the training set
predictedY = model.predict(trainX)

# print quality metrics
print('\nTraining Classification Report:\n\n', classification_report(trainY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

# print quality metrics
print('\nTesting Classification Report:\n\n', classification_report(testY, predictedY))

# predict the labels of the test set
predictedY = model.predict(testX)

print('\nTesting Confusion Matrix:\n')

sn.heatmap(confusion_matrix(testY, predictedY))
plt.figure()
# Out:
# [0]	validation_0-mlogloss:2.13161
# [1]	validation_0-mlogloss:2.02609
# [2]	validation_0-mlogloss:1.94776
# [3]	validation_0-mlogloss:1.88604
# [4]	validation_0-mlogloss:1.83204
# [5]	validation_0-mlogloss:1.78916
# [6]	validation_0-mlogloss:1.75547
# [7]	validation_0-mlogloss:1.72422
# [8]	validation_0-mlogloss:1.69861
# [9]	validation_0-mlogloss:1.67655
# [10]	validation_0-mlogloss:1.65285
# [11]	validation_0-mlogloss:1.63435
# [12]	validation_0-mlogloss:1.61718
# [13]	validation_0-mlogloss:1.60097
# [14]	validation_0-mlogloss:1.58698
# [15]	validation_0-mlogloss:1.57375
# [16]	validation_0-mlogloss:1.56162
# [17]	validation_0-mlogloss:1.55080
# [18]	validation_0-mlogloss:1.53923
# [19]	validation_0-mlogloss:1.52839
# [20]	validation_0-mlogloss:1.51995
# [21]	validation_0-mlogloss:1.51195
# [22]	validation_0-mlogloss:1.50367
# [23]	validation_0-mlogloss:1.49582
# [24]	validation_0-mlogloss:1.48907
# [25]	validation_0-mlogloss:1.48348
# [26]	validation_0-mlogloss:1.47559
# [27]	validation_0-mlogloss:1.46799
# [28]	validation_0-mlogloss:1.46244
# [29]	validation_0-mlogloss:1.45585
# [30]	validation_0-mlogloss:1.45015
# [31]	validation_0-mlogloss:1.44564
# [32]	validation_0-mlogloss:1.44115
# [33]	validation_0-mlogloss:1.43509
# [34]	validation_0-mlogloss:1.43098
# [35]	validation_0-mlogloss:1.42620
# [36]	validation_0-mlogloss:1.42253
# [37]	validation_0-mlogloss:1.41870
# [38]	validation_0-mlogloss:1.41596
# [39]	validation_0-mlogloss:1.41204
# [40]	validation_0-mlogloss:1.40853
# [41]	validation_0-mlogloss:1.40554
# [42]	validation_0-mlogloss:1.40231
# [43]	validation_0-mlogloss:1.39884
# [44]	validation_0-mlogloss:1.39579
# [45]	validation_0-mlogloss:1.39310
# [46]	validation_0-mlogloss:1.39088
# [47]	validation_0-mlogloss:1.38842
# [48]	validation_0-mlogloss:1.38564
# [49]	validation_0-mlogloss:1.38259
# [50]	validation_0-mlogloss:1.37965
# [51]	validation_0-mlogloss:1.37650
# [52]	validation_0-mlogloss:1.37556
# [53]	validation_0-mlogloss:1.37332
# [54]	validation_0-mlogloss:1.36993
# [55]	validation_0-mlogloss:1.36695
# [56]	validation_0-mlogloss:1.36499
# [57]	validation_0-mlogloss:1.36355
# [58]	validation_0-mlogloss:1.36174
# [59]	validation_0-mlogloss:1.35939
# [60]	validation_0-mlogloss:1.35707
# [61]	validation_0-mlogloss:1.35456
# [62]	validation_0-mlogloss:1.35302
# [63]	validation_0-mlogloss:1.35180
# [64]	validation_0-mlogloss:1.34881
# [65]	validation_0-mlogloss:1.34754
# [66]	validation_0-mlogloss:1.34635
# [67]	validation_0-mlogloss:1.34537
# [68]	validation_0-mlogloss:1.34356
# [69]	validation_0-mlogloss:1.34171
# [70]	validation_0-mlogloss:1.33979
# [71]	validation_0-mlogloss:1.33818
# [72]	validation_0-mlogloss:1.33659
# [73]	validation_0-mlogloss:1.33506
# [74]	validation_0-mlogloss:1.33316
# [75]	validation_0-mlogloss:1.33205
# [76]	validation_0-mlogloss:1.33119
# [77]	validation_0-mlogloss:1.32985
# [78]	validation_0-mlogloss:1.32886
# [79]	validation_0-mlogloss:1.32615
# [80]	validation_0-mlogloss:1.32470
# [81]	validation_0-mlogloss:1.32238
# [82]	validation_0-mlogloss:1.32098
# [83]	validation_0-mlogloss:1.31916
# [84]	validation_0-mlogloss:1.31821
# [85]	validation_0-mlogloss:1.31646
# [86]	validation_0-mlogloss:1.31478
# [87]	validation_0-mlogloss:1.31320
# [88]	validation_0-mlogloss:1.31157
# [89]	validation_0-mlogloss:1.31051
# [90]	validation_0-mlogloss:1.30940
# [91]	validation_0-mlogloss:1.30816
# [92]	validation_0-mlogloss:1.30656
# [93]	validation_0-mlogloss:1.30678
# [94]	validation_0-mlogloss:1.30578
# [95]	validation_0-mlogloss:1.30509
# [96]	validation_0-mlogloss:1.30373
# [97]	validation_0-mlogloss:1.30285
# [98]	validation_0-mlogloss:1.30247
# [99]	validation_0-mlogloss:1.30184
#
# Training Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      5000
#            1       1.00      1.00      1.00      5000
#            2       0.97      0.98      0.98      5000
#            3       0.99      0.97      0.98      5000
#            4       0.95      0.98      0.97      5000
#            5       0.99      0.97      0.98      5000
#            6       0.98      0.99      0.98      5000
#            7       1.00      0.99      0.99      5000
#            8       0.99      0.99      0.99      5000
#            9       1.00      0.99      1.00      5000
#
#     accuracy                           0.99     50000
#    macro avg       0.99      0.99      0.99     50000
# weighted avg       0.99      0.99      0.99     50000
#
#
# Testing Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.64      0.61      0.62       523
#            1       0.63      0.62      0.63       510
#            2       0.42      0.39      0.40       487
#            3       0.39      0.38      0.39       510
#            4       0.46      0.45      0.45       505
#            5       0.45      0.45      0.45       489
#            6       0.55      0.63      0.59       509
#            7       0.60      0.57      0.58       483
#            8       0.64      0.67      0.65       479
#            9       0.57      0.58      0.58       505
#
#     accuracy                           0.54      5000
#    macro avg       0.53      0.54      0.53      5000
# weighted avg       0.53      0.54      0.53      5000
#
#
# Testing Confusion Matrix:
